# %%
from awpy import Demo
dem = Demo("/home/lz80/astralis-vs-vitality-m1-inferno.dem")

dem.parse(player_props=["health", "armor_value", "pitch", "yaw", "current_equip_value"])

# %%
dem.ticks
# Out:
# shape: (1_286_210, 14)
# ┌────────┬────────────┬───────┬─────────────────┬───┬────────┬────────────────┬────────┬───────────┐
# │ health ┆ place      ┆ armor ┆ current_equip_v ┆ … ┆ tick   ┆ steamid        ┆ name   ┆ round_num │
# │ ---    ┆ ---        ┆ ---   ┆ alue            ┆   ┆ ---    ┆ ---            ┆ ---    ┆ ---       │
# │ i32    ┆ str        ┆ i32   ┆ ---             ┆   ┆ i32    ┆ u64            ┆ str    ┆ u64       │
# │        ┆            ┆       ┆ u32             ┆   ┆        ┆                ┆        ┆           │
# ╞════════╪════════════╪═══════╪═════════════════╪═══╪════════╪════════════════╪════════╪═══════════╡
# │ 100    ┆ TSpawn     ┆ 0     ┆ 200             ┆ … ┆ 1      ┆ 76561197978835 ┆ flameZ ┆ 1         │
# │        ┆            ┆       ┆                 ┆   ┆        ┆ 160            ┆        ┆           │
# │ 100    ┆ TSpawn     ┆ 0     ┆ 200             ┆ … ┆ 1      ┆ 76561197973140 ┆ mezii  ┆ 1         │
# ...
